# %% [markdown]
# An implementation of sequence to sequence learning for performing the following op
# Input: "535+61"
# Output: "596"

# %%
#Importing everything that is needed
from __future__ import print_function
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"  # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"] = "1"  # Will use only 2nd, 3rd and 4th gpu

from keras.models import Sequential
from keras import layers
import numpy as np
from six.moves import range
import random
# Out:
# Using TensorFlow backend.

# %%
#Parameters
TRAIN_DATA = 5000
TEST_DATA = int(TRAIN_DATA * 0.5)

chars = '0123456789 abcdefghijklmnopqrstuvwxyz'

#NN parameters
RNN = layers.LSTM
HIDDEN_SIZE = 256
BATCH_SIZE = 128
LAYERS = 3
ITERATIONS = 200

MAX_LEN_X = 6
MAX_LEN_Y = int( (6 / 3) * (99 + 1) )

class colors:
    ok = '\033[92m'
    fail = '\033[91m'
    close = '\033[0m'

# %%
class CharacterTable():
    """
    Given a set of chars:
    - encode them to one hot integer representations
    - decode the one hot integer representations to their original chars
    - decode a vector of pr
    """
    def __init__(self, chars):
        """
        Initialise character table
        """
        self.chars = sorted(set(chars))
        self.char_to_nr = dict( (ch, nr) for nr, ch in enumerate(self.chars) )
        self.nr_to_char = dict( (nr, ch) for nr, ch in enumerate(self.chars) )
        
    def encode(self, str, num_rows):
        """
        One hot encodes str
        params: num_rows for keeping the num_rows the same
        """
        
        #Matrice of zeros with the following shape [number_of_lines][total_chars_per_line]
        x = np.zeros((num_rows, len(self.chars)))
        
        #Do the encoding
        for i, ch in enumerate(str):
            x[i, self.char_to_nr[ch]] = True
        
        return x
        
    def decode(self, x, calc_argmax = True):
        """
        Decodes x and returns it
        """
        if calc_argmax:
            x = x.argmax(axis = -1)
        
        return ''.join(self.nr_to_char[x] for x in x)

# %%
#Generator for the data
class GenerateData():
    """
    Generate train & test data for the NN
    """
    
    def __init__(self, n_train, n_test, max_len):
        chars = 'abcdefghijklmnopqrstuvwxyz'
        self.char_to_nr = dict( (ch, nr) for nr, ch in enumerate(chars) )
        self.nr_to_char = dict( (nr, ch) for nr, ch in enumerate(chars) )
        self.n_train = n_train
        self.n_test = n_test
        self.max_len = max_len
        
    def generateAll(self):
        x1, y1 = self.generate(self.n_train, self.max_len)
        x2, y2 = self.generate(self.n_test, self.max_len)
        return x1, y1, x2, y2
    
    def generate(self, n, max_len):
        """
        Generate n data of the form x,y (with max max_len length per data)
        """
        x = []
        y = []
        for i in range(n):
            crt_x = ''
            crt_y = ''
            
            for j in range(max_len[0] / 3):
                crt_nr = random.randint(1, 99)
                crt_ch = self.nr_to_char[random.randint(0, 25)]
                
                crt_x += str(crt_nr) + crt_ch
                for h in range(crt_nr):
                    crt_y += crt_ch
                
            while len(crt_y) < max_len[1]:
                 crt_y += ' '
                
            x.append(crt_x)
            y.append(crt_y)
        
        return x, y

# %%
#Generate & Vectorise data
generator = GenerateData(TRAIN_DATA, TEST_DATA, (MAX_LEN_X, MAX_LEN_Y))
encoder = CharacterTable(chars)

x_train_aux, y_train_aux, x_test_aux, y_test_aux = generator.generateAll()

x_train = np.zeros( (TRAIN_DATA, MAX_LEN_X, len(chars)), dtype = np.bool )
x_test = np.zeros( (TEST_DATA, MAX_LEN_X, len(chars)), dtype = np.bool )
y_train = np.zeros( (TRAIN_DATA, MAX_LEN_Y, len(chars)), dtype = np.bool )
y_test = np.zeros( (TEST_DATA, MAX_LEN_Y, len(chars)), dtype = np.bool )

for i, line in enumerate(x_train_aux):
    x_train[i] = encoder.encode(line, MAX_LEN_X)

for i, line in enumerate(x_test_aux):
    x_test[i] = encoder.encode(line, MAX_LEN_X) 
    
for i, line in enumerate(y_train_aux):
    y_train[i] = encoder.encode(line, MAX_LEN_Y)

for i, line in enumerate(y_test_aux):
    y_test[i] = encoder.encode(line, MAX_LEN_Y)

# %%
print("Training data: ", x_train.shape, ", ", y_train.shape)
print("Testing data: ", x_test.shape, ", ", y_test.shape)
# Out:
# Training data:  (5000, 6, 37) ,  (5000, 200, 37)
# Testing data:  (2500, 6, 37) ,  (2500, 200, 37)

# %%
#Build the model

model = Sequential()

model.add(RNN(
    HIDDEN_SIZE,
    input_shape= ( MAX_LEN_X, len(chars) ) #input shape = (SIZE_OF_LINE_X, NUMBER_OF_DISTINCT_CHARS)
    )
)
model.add(layers.RepeatVector(MAX_LEN_Y))

for _ in range(LAYERS):
    model.add(RNN(HIDDEN_SIZE, return_sequences=True))
  
model.add(layers.TimeDistributed(layers.Dense(len(chars))))
model.add(layers.Activation('softmax'))
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# lstm_1 (LSTM)                    (None, 256)           301056      lstm_input_1[0][0]
# ____________________________________________________________________________________________________
# repeatvector_1 (RepeatVector)    (None, 200, 256)      0           lstm_1[0][0]
# ____________________________________________________________________________________________________
# lstm_2 (LSTM)                    (None, 200, 256)      525312      repeatvector_1[0][0]
# ____________________________________________________________________________________________________
# lstm_3 (LSTM)                    (None, 200, 256)      525312      lstm_2[0][0]
# ____________________________________________________________________________________________________
# lstm_4 (LSTM)                    (None, 200, 256)      525312      lstm_3[0][0]
# ____________________________________________________________________________________________________
# timedistributed_1 (TimeDistribut (None, 200, 37)       9509        lstm_4[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 200, 37)       0           timedistributed_1[0][0]
# ====================================================================================================
# Total params: 1,886,501
# Trainable params: 1,886,501
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# /usr/local/lib/python2.7/dist-packages/keras/engine/topology.py:368: UserWarning: The `regularizers` property of layers/models is deprecated. Regularization losses are now managed via the `losses` layer/model property.
#   warnings.warn('The `regularizers` property of '

# %%
#Train the model

for iteration in range(ITERATIONS):
    print()
    print("Iteration: ", iteration)
    
    model.fit(x_train, y_train,
             batch_size = BATCH_SIZE,
             nb_epoch = 1,
             validation_data = (x_test, y_test))
    
    #Select 10 samples from the validation data
    for i in range(10):
        ind = np.random.randint(0, len(x_test))
        rowx, rowy = x_test[np.array([ind])], y_test[np.array([ind])]
        
        preds = model.predict_classes(rowx, verbose = 0)
        q = encoder.decode(rowx[0])
        correct = encoder.decode(rowy[0])
        guess = encoder.decode(preds[0], calc_argmax = False)
        
        print('Q', q)
        print('T', correct)
        if correct == guess:
            print(colors.ok + 'K' + colors.close, end=" ")
        else:
            print(colors.fail + 'N' + colors.close, end=" ")
        print(guess)
# Out:
# Iteration:  0
# Train on 5000 samples, validate on 2500 samples
# Epoch 1/1
# 5000/5000 [==============================] - 44s - loss: 2.2482 - acc: 0.4905 - val_loss: 1.9789 - val_acc: 0.5053
# Q 78e75g
# T eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggg
# N   ccccccccccnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnfffffff
# Q 35v79i
# T vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvviiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii
# N    cccccccnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnffffff
# Q 89e36o
# T eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeoooooooooooooooooooooooooooooooooooo
# N    cccccccnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnfffffff
# Q 11o57t
# T ooooooooooottttttttttttttttttttttttttttttttttttttttttttttttttttttttt
# N
# Q 70h72g
# T hhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhgggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggg
# N      ccccbbbnnnnnnnnnnnnnnnnnnnnnnnnffffffff
# Q 51e97y
# T eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyy
# N    ccccccccnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnffffffff
# Q 29d11p
# T dddddddddddddddddddddddddddddppppppppppp
# N
# Q 39e84f
# T eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# N    ccccccccnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnfffffffff
# Q 76r78n
# T rrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
# N   cccccccccnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnfffffff
# Q 18s23n
# T ssssssssssssssssssnnnnnnnnnnnnnnnnnnnnnnn
# N           bbbbnnnnnnnnnnnnnfffffffff
#
# Iteration:  1
# Train on 5000 samples, validate on 2500 samples
# Epoch 1/1
# 5000/5000 [==============================] - 42s - loss: 1.9108 - acc: 0.5074 - val_loss: 1.8612 - val_acc: 0.5070
# Q 77q43b
# T qqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb
# N   ccccnnneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# Q 12w87y
# T wwwwwwwwwwwwyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyy
# N    ccccnnnneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# Q 53a47a
# T aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa
# N    ccaaannneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# Q 8u26b
# T uuuuuuuubbbbbbbbbbbbbbbbbbbbbbbbbb
# N    ccccnnneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# Q 43t58a
# T tttttttttttttttttttttttttttttttttttttttttttaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa
# N    cccannnneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# Q 70m46m
# T mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm
# N   ccccfffeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# Q 8g45w
# T ggggggggwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww
# N    ccccnnnneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# Q 32v20m
# T vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvmmmmmmmmmmmmmmmmmmmm
# N        nnnnnnnnnnnnnnnn
# Q 61w77w
# T wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww
# N   ccccfnneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# Q 73x56i
# T xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii
# N   ccccnnnneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
#
# Iteration:  2
# Train on 5000 samples, validate on 2500 samples
# Epoch 1/1
# 5000/5000 [==============================] - 44s - loss: 1.8430 - acc: 0.5181 - val_loss: 1.8101 - val_acc: 0.5310
# Q 75d96t
# T dddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddtttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttt
# N   cddddddddttttttttttttttttttttttttttttttttttttttttttttttttttttttttdddddddddddddddlllllllllll
# Q 49p57b
# T pppppppppppppppppppppppppppppppppppppppppppppppppbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb
# N  cccccdddddddddtttttttttttttttttttttttttttttttttddddddddddddddddddddddllllllllll
# Q 7g86u
# T ggggggguuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuu
# N   gggggggffffffffgggggggggggggggggggggggggggggggggeeeeeeeeeeeeeeeee
# Q 49a76o
# T aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaoooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooo
# N   cccdddddddddddddtttttttttttttttttttttttiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiikkk
# Q 62i23t
# T iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiittttttttttttttttttttttt
# N     cjjjjddddddddddjjjjjjdllllllllllllll
# Q 14e59q
# T eeeeeeeeeeeeeeqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqq
# N    ccceeeeeeeeeeeeeeeeiiiiiiiiiiiiiiiiiiiiiiiiikkkkk
# Q 82i42y
# T iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyy
# N   ccccccddddeeeeeeeiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiikk
# Q 50s6a
# T ssssssssssssssssssssssssssssssssssssssssssssssssssaaaaaa
# N       ccddddddddddjjjjjdddddllllllllll
# Q 47m9k
# T mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmkkkkkkkkk
# N     ccaaaaaaaagggggggggggggggggggggggggggggg
# Q 39u74k
# T uuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuukkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk
# N   ccaddddddddddddttttttttttttttttiiiiiiiiiiiiiiiiiiiiiillllllliiiiiiiiiii
#
# Iteration:  3
# Train on 5000 samples, validate on 2500 samples
# Epoch 1/1
# 5000/5000 [==============================] - 43s - loss: 1.7113 - acc: 0.5416 - val_loss: 1.6728 - val_acc: 0.5441
# Q 11r85d
# T rrrrrrrrrrrddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddd
# N    dddddddddddddddddddddddddddddddddddddddddddddddddddddddd
# Q 20d53b
# T ddddddddddddddddddddbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb
# N nsssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssyyyyyyyyyyssssssss
# Q 66i46p
# T iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiipppppppppppppppppppppppppppppppppppppppppppppp
# N    llllllllliiiiiiiiikkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk
# Q 44e89t
# T eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeettttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttt
# N nplljjjjjjjjjllllllllqqqqqqqqddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddd
# Q 70a85n
# T aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaannnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
# N  lllllllaaaaaaaiiiiiiiiiaaaaakkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk
# Q 65q27b
# T qqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqbbbbbbbbbbbbbbbbbbbbbbbbbbb
# N nncndddddddddddddddddddddddddddddssssssssssssssssssssssssssddddddddddddddxxxxxxxxxxxxxxxxxxxxxxxx
# Q 41h65z
# T hhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# N     zzzzzooooooooooooooooooooooooooooooooooooooooooooooooooooookkkkkkzzz
# Q 78n40h
# T nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh
# N npllllllaaaaaaaaaaaarkkkkkkkkkrrrrrkkkkkkkkkkkkkkkkkkkkkkkkkkkkkrrrrrkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk
# Q 9r29x
# T rrrrrrrrrxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# N n  ccccccccxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# Q 21j9s
# T jjjjjjjjjjjjjjjjjjjjjsssssssss
# N n ssttttddddddddddddddddddddddddddddddddtttt
#
# Iteration:  4
# Train on 5000 samples, validate on 2500 samples
# Epoch 1/1
# 5000/5000 [==============================] - 43s - loss: 1.5766 - acc: 0.5612 - val_loss: 1.5509 - val_acc: 0.5787
# Q 4s70a
# T ssssaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa
# N ncssssssssssssssssssqqqqqqqqqqqq
# Q 6j30u
# T jjjjjjuuuuuuuuuuuuuuuuuuuuuuuuuuuuuu
# N ussssssssssuuuuuuuuuuuuuuuuuuuuuu
# Q 90w38u
# T wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuu
# N uuyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuyyyyyyyyyyyyyyyyyyyyyyyyyyyy
# Q 8j53b
# T jjjjjjjjbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb
# N cccccccccccccbbbbbbbbbbbbbbbwwwwwwwqqqqqq
# Q 56q16r
# T qqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqrrrrrrrrrrrrrrrr
# N ccccccqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqrrrrrr
# Q 38y94o
# T yyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyoooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooo
# N uxxyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyy
# Q 24x51q
# T xxxxxxxxxxxxxxxxxxxxxxxxqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqq
# N cxxxxxxxxxxxxqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqq
# Q 32b88f
# T bbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# N uffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# Q 48b95s
# T bbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbsssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss
# N uxxxyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyybbbbbbbbbbbyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyy
# Q 47g92d
# T gggggggggggggggggggggggggggggggggggggggggggggggdddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddddd
# N ucccccccceeeeeeepppppppppppppuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuqqqqqqqqqqqqqqqqqqq
#
# Iteration:  5
# Train on 5000 samples, validate on 2500 samples
# Epoch 1/1
# 5000/5000 [==============================] - 43s - loss: 1.4298 - acc: 0.5964 - val_loss: 1.3765 - val_acc: 0.5959
# Q 62y51s
# T yyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyysssssssssssssssssssssssssssssssssssssssssssssssssss
# N uyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyy
# Q 53y61g
# T yyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggg
# N uuuffffffffffffffffffffffffffffffffffffgggggggggggggggggggggggggggggggggggggggggggggggggggggggg
# Q 43s1s
# T ssssssssssssssssssssssssssssssssssssssssssss
# N nsssssssssssssssssssdddddddddd
# Q 36k35j
# T kkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj
# N pijjjjjjrrrrrrrrrrrrrrrrrrrrrrrrrrrjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj
# Q 61a15j
# T aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaajjjjjjjjjjjjjjj
# N pjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj
# Q 50h56g
# T hhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhgggggggggggggggggggggggggggggggggggggggggggggggggggggggg
# N phvvvvoooooooooooooooooooooooooooooooooooooooooooooooooooovvvvvvvvvvvvvvvvvvvvvvvvvvgggggggggggggggggmmmmm
# Q 18m79r
# T mmmmmmmmmmmmmmmmmmrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrr
# N cmmmmmmmmmmmmmmmmmmmmmmmmmmzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# Q 36b82j
# T bbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj
# N ncccnnnnnnnnnnnnnxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxnnnnnnnnnnnnnnnnnnqqqjjjjjjjjjjjjjjjjjjj
# Q 32i71v
# T iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiivvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# N piiiaaaaaaaavooooooooogggggggggggggggggggmmmmmmmmmmmmmmmmmmmmmmmmmmmmggggggggggggggg
# Q 24d74y
# T ddddddddddddddddddddddddyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyy
# N uyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyy
#
# Iteration:  6
# Train on 5000 samples, validate on 2500 samples
# Epoch 1/1
# 5000/5000 [==============================] - 43s - loss: 1.3166 - acc: 0.6164 - val_loss: 1.2918 - val_acc: 0.6224
# Q 42r52m
# T rrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm
# N ahhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhmmmmmmmmmooooooooooooooooooooooooooo
# Q 24j37d
# T jjjjjjjjjjjjjjjjjjjjjjjjddddddddddddddddddddddddddddddddddddd
# N pqdddqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqq
# Q 12w24t
# T wwwwwwwwwwwwtttttttttttttttttttttttt
# N iittttttttttttttttttttttttttttttttttttt
# Q 3t73p
# T tttppppppppppppppppppppppppppppppppppppppppppppppppppppppppppppppppppppppppp
# N itttttttttttttttttttttttttttttttttttttttiiiiiiiiiii
# Q 75x84z
# T xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# N nxxxxxxxxxxxxxxxxbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb
# Q 75f72r
# T fffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrr
# N efffffffffeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeffffffffffeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# Q 80c39i
# T cccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccciiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii
# N naaaaaccooooooooooooooooooooooooooooooooooooooooooooooooooooocccccccccccccccccoooooooooooooooccccccccccccccccccccccccaaaaaaaaaaaaaaaaaaaaaa
# Q 56n18u
# T nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnuuuuuuuuuuuuuuuuuu
# N nuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuu
# Q 61c68u
# T cccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuu
# N nuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuggggggggggggggggguuuuuuuuuuuuuuuuuuuuuuu
# Q 10n67e
# T nnnnnnnnnneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# N nnnnnnnnneeennnnnnnnnnbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb
#
# Iteration:  7
# Train on 5000 samples, validate on 2500 samples
# Epoch 1/1
# 5000/5000 [==============================] - 43s - loss: 1.0727 - acc: 0.6792 - val_loss: 0.9496 - val_acc: 0.7156
# Q 64w62j
# T wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj
# N qqqqqqqqqqqqqqqqqwwwwwwwwwwwwwwwqqqqqqqqqqqqqqqqqqqqqqqqqqqqqjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj
# Q 87h15s
# T hhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhsssssssssssssss
# N nhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhwwqqqqqqqqqqqqqyyyyyyyyyyyyyyyyyy
# Q 47m9k
# T mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmkkkkkkkkk
# N ggggggggggggggggggggggggggggggggggggggkkkkkkkkkkkk
# Q 34u13n
# T uuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuunnnnnnnnnnnnn
# N nnnnnuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuu
# Q 72x36a
# T xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa
# N nxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxaaaaaaaaaaaaaaarrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrr
# Q 16s84f
# T ssssssssssssssssffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# N nssssuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuffffffffffffffffffffffffffffffffffffffffffffffffffff
# Q 16w80f
# T wwwwwwwwwwwwwwwwffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# N uyyyyyyyyyyyyfffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# Q 36r69f
# T rrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrfffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# N aeggggggggggggggggggggggggggggggggggggffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# Q 29p78h
# T ppppppppppppppppppppppppppppphhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh
# N iiippppppppppppppppjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjhhwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww
# Q 46t90r
# T ttttttttttttttttttttttttttttttttttttttttttttttrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrr
# N iittttttttttttttttttttttttttttttttttttttttttiiiiiiiiiiiiiiiiiikkkkkkkkkkkkkkkkkkkkkkrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrr
#
# Iteration:  8
# Train on 5000 samples, validate on 2500 samples
# Epoch 1/1
# 5000/5000 [==============================] - 44s - loss: 0.7878 - acc: 0.7620 - val_loss: 0.7216 - val_acc: 0.7838
# Q 65i10q
# T iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiqqqqqqqqqq
# N iiiiiiilllllllllllllliiiiiiiiiiiiiiiiiiiiiiiiiiiiiiilllllliiiiiiiiiiiiiiiipppp
# Q 94i26s
# T iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiissssssssssssssssssssssssss
# N iiiiiilllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllssssssssssssssssssssssss
# Q 25m56h
# T mmmmmmmmmmmmmmmmmmmmmmmmmhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh
# N whhhhmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh
# Q 10q73y
# T qqqqqqqqqqyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyy
# N qyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyy
# Q 32o62f
# T ooooooooooooooooooooooooooooooooffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# N eeeeoeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeffffffffffffffffff
# Q 84i58j
# T iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiijjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj
# N iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiijjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj
# Q 76s84e
# T sssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssseeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# N nnsssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb
# Q 67v21w
# T vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvwwwwwwwwwwwwwwwwwwwww
# N vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvggggggggggggggggggggggggwwwwwwwww
# Q 36k35j
# T kkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj
# N ikkkkkkkkkkkkkkkkkkkkkkkkkklllllllllllllllllllllllllllllllllll
# Q 73e45l
# T eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeelllllllllllllllllllllllllllllllllllllllllllll
# N eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeegggggggkkkkkkkkkkkkkkkkkiiiiiillllllliiiiiiiiilllll
#
# Iteration:  9
# Train on 5000 samples, validate on 2500 samples
# Epoch 1/1
# 5000/5000 [==============================] - 43s - loss: 0.6231 - acc: 0.8187 - val_loss: 0.5792 - val_acc: 0.8343
# Q 15m10h
# T mmmmmmmmmmmmmmmhhhhhhhhhh
# N hhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh
# Q 52w91u
# T wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuu
# N qwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwyyyyyyyyyyyyyyyyyyyyuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuu
# Q 1e92q
# T eqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqq
# N qezzzzzzzzzzzzwqqqqqqqqqqqqqqqqqqqqqqqqqqqqqq
# Q 3r63n
# T rrrnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
# N aarrrrrrrrrrrrrrrrrrrrrrannnnnnnnnnnnnnnnnnnnnnnnn
# Q 44t7o
# T ttttttttttttttttttttttttttttttttttttttttttttooooooo
# N iittttttttttttttttttttttinnnnneeeooooooooooooooooooooooooooooooooooooooooo
# Q 27v81j
# T vvvvvvvvvvvvvvvvvvvvvvvvvvvjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj
# N vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvalllllllljjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj
# Q 79u20e
# T uuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuueeeeeeeeeeeeeeeeeeee
# N uuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuueeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# Q 66h67i
# T hhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii
# N hhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiaaaaaaaaaaaaiilllll
# Q 33q96y
# T qqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyy
# N qqqqqqqqqqqqqqqqqqqqqqqqqqqqqqyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyy
# Q 47v62w
# T vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww
# N vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvmmmmmmmwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww
#
# Iteration:  10
# Train on 5000 samples, validate on 2500 samples
# Epoch 1/1
# 5000/5000 [==============================] - 44s - loss: 0.4740 - acc: 0.8684 - val_loss: 0.3861 - val_acc: 0.8977
# Q 50s98g
# T ssssssssssssssssssssssssssssssssssssssssssssssssssgggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggg
# N usssssssssssssssssssssssssssssssssssssssssssssssssssssssssssddddpppppppppppppppppgggggggggggggggggggggggggggggggggggggggggggggggggggggggggg
# Q 19o85s
# T ooooooooooooooooooosssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss
# N eoooooooooooooooooooobbbnnnnnnsssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss
# Q 59w59v
# T wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# N wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# Q 88w93s
# T wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwsssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss
# N wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwsssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssdddddd
# Q 91i78h
# T iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiihhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh
# N iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiihhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh
# Q 7f33w
# T fffffffwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww
# N fffffffffffffffffffffffff
# Q 36v44n
# T vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
# N cvvvvvvvvvvvvvvvvvvvvvvvvvvvvvcccccccnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
# Q 18s11z
# T sssssssssssssssssszzzzzzzzzzz
# N sssssssssssssssssssssssss
# Q 44b4n
# T bbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbnnnn
# N bbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbnnnnnnnn
# Q 47m9k
# T mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmkkkkkkkkk
# N ggggmmmmmmmzzzzzzzzzzzzzzzzzzzkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk
#
# Iteration:  11
# Train on 5000 samples, validate on 2500 samples
# Epoch 1/1
# 5000/5000 [==============================] - 43s - loss: 0.3290 - acc: 0.9129 - val_loss: 0.3140 - val_acc: 0.9191
# Q 19p92h
# T ppppppppppppppppppphhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh
# N ppppppppppppppppppppphhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh
# Q 82j32y
# ...
# Q 16s81w
# T sssssssssssssssswwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww
# K sssssssssssssssswwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww
# Q 39d95a
# T dddddddddddddddddddddddddddddddddddddddaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa
# N ddddddddddddddddddddddddddddddddddddddddaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa
# Q 87h15s
# T hhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhsssssssssssssss
# N hhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhssssssssssssss
# Q 98b32b
# T bbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb
# N bbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb
# Q 91k25q
# T kkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkqqqqqqqqqqqqqqqqqqqqqqqqq
# N kkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkqqqqqqqqqqqqqqqqqqqqqqqqqq
# Q 13c21m
# T cccccccccccccmmmmmmmmmmmmmmmmmmmmm
# K cccccccccccccmmmmmmmmmmmmmmmmmmmmm
# Q 78m74v
# T mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# N mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
#
# Iteration:  142
# Train on 5000 samples, validate on 2500 samples
# Epoch 1/1
# 5000/5000 [==============================] - 43s - loss: 0.0146 - acc: 0.9940 - val_loss: 0.0156 - val_acc: 0.9940
# Q 20q54d
# T qqqqqqqqqqqqqqqqqqqqdddddddddddddddddddddddddddddddddddddddddddddddddddddd
# K qqqqqqqqqqqqqqqqqqqqdddddddddddddddddddddddddddddddddddddddddddddddddddddd
# Q 26p65b
# T ppppppppppppppppppppppppppbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb
# K ppppppppppppppppppppppppppbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb
# Q 41i87f
# T iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiifffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# N iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiifffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# Q 77f6a
# T fffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffaaaaaa
# N fffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffaaaaaaa
# Q 98b21z
# T bbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbzzzzzzzzzzzzzzzzzzzzz
# K bbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbzzzzzzzzzzzzzzzzzzzzz
# Q 43l57o
# T lllllllllllllllllllllllllllllllllllllllllllooooooooooooooooooooooooooooooooooooooooooooooooooooooooo
# N llllllllllllllllllllllllllllllllllllllllllloooooooooooooooooooooooooooooooooooooooooooooooooooooooooo
# Q 46h5i
# T hhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhiiiii
# K hhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhiiiii
# Q 53l87q
# T lllllllllllllllllllllllllllllllllllllllllllllllllllllqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqq
# N llllllllllllllllllllllllllllllllllllllllllllllllllllqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqq
# Q 90h7j
# T hhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhjjjjjjj
# K hhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhjjjjjjj
# Q 84i68s
# T iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiissssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss
# N iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiissssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss
#
# Iteration:  143
# Train on 5000 samples, validate on 2500 samples
# Epoch 1/1
# 5000/5000 [==============================] - 44s - loss: 0.0112 - acc: 0.9956 - val_loss: 0.0284 - val_acc: 0.9899
# Q 43z26s
# T zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzssssssssssssssssssssssssss
# N zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzsssssssssssssssssssssssss
# Q 63u88j
# T uuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuujjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj
# N uuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuujjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj
# Q 93i48x
# T iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiixxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# N iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiixxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Q 6i16l
# T iiiiiillllllllllllllll
# K iiiiiillllllllllllllll
# Q 67j59j
# T jjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj
# N jjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj
# Q 93x77t
# T xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttt
# N xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttt
# Q 20x85a
# T xxxxxxxxxxxxxxxxxxxxaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa
# K xxxxxxxxxxxxxxxxxxxxaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa
# Q 66b94b
# T bbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb
# N bbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb
# Q 93n37p
# T nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnppppppppppppppppppppppppppppppppppppp
# N nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnppppppppppppppppppppppppppppppppppppp
# Q 57y45b
# T yyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyybbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb
# N yyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyybbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb
#
# Iteration:  144
# Train on 5000 samples, validate on 2500 samples
# Epoch 1/1
#  768/5000 [===>..........................] - ETA: 34s - loss: 0.0620 - acc: 0.9838
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-865e6b690898> in <module>()
#       8              batch_size = BATCH_SIZE,
#       9              nb_epoch = 1,
# ---> 10              validation_data = (x_test, y_test))
#      11
#      12     #Select 10 samples from the validation data
#
# /usr/local/lib/python2.7/dist-packages/keras/models.pyc in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, **kwargs)
#     662                               shuffle=shuffle,
#     663                               class_weight=class_weight,
# --> 664                               sample_weight=sample_weight)
#     665
#     666     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch)
#    1141                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1142                               callback_metrics=callback_metrics,
# -> 1143                               initial_epoch=initial_epoch)
#    1144
#    1145     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.pyc in _fit_loop(self, f, ins, out_labels, batch_size, nb_epoch, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch)
#     841                 batch_logs['size'] = len(batch_ids)
#     842                 callbacks.on_batch_begin(batch_index, batch_logs)
# --> 843                 outs = f(ins_batch)
#     844                 if not isinstance(outs, list):
#     845                     outs = [outs]
#
# /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    1601         session = get_session()
#    1602         updated = session.run(self.outputs + [self.updates_op],
# -> 1603                               feed_dict=feed_dict)
#    1604         return updated[:len(self.outputs)]
#    1605
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
import pydotplus
from IPython.display import SVG
from keras.utils.visualize_util import model_to_dot

SVG(model_to_dot(model).create(prog='dot', format='svg'))
